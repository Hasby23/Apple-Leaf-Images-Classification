# %% [markdown]
# ## Pre Process

# %%
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from PIL import Image
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
PATH_train = 'Apple/'
IMAGE_SIZE = 128
BATCH_SIZE = 32

# %%
data = []
label = []

class_total = np.sort(os.listdir(PATH_train))

for class_name in class_total:
    print(f'Name: {class_name}')
    for file_total in tqdm(os.listdir(PATH_train + class_name)):
        names = class_total
        names = np.where(names != class_name, 0.0, names)
        names = np.where(names == class_name, 1.0, names)
        image_file = PATH_train + class_name +'/'+ file_total
        data.append(np.asarray(Image.open(image_file).resize((IMAGE_SIZE, IMAGE_SIZE)).convert('RGB')))
        label.append(names)
# Out:
# Name: Apple___Apple_scab
# 100%|██████████| 630/630 [00:01<00:00, 383.45it/s]
# Name: Apple___Black_rot
# 100%|██████████| 621/621 [00:01<00:00, 567.32it/s]
# Name: Apple___Cedar_apple_rust
# 100%|██████████| 275/275 [00:00<00:00, 618.62it/s]
# Name: Apple___healthy
# 100%|██████████| 1645/1645 [00:02<00:00, 601.14it/s]

# %%
data = np.array(data, dtype='float32') / 255
label = np.array(label, dtype='float32')

# %%
train_ratio = 0.80
validation_ratio = 0.10
test_ratio = 0.10

# %%
x_train, x_test, y_train, y_test = train_test_split(data, label, test_size = 1 - train_ratio, random_state=123)

# %%
x_val, x_test, y_val, y_test = train_test_split(x_test, y_test, test_size=test_ratio / (test_ratio + validation_ratio), random_state=123)

# %%
print(f'Data: {np.shape(data)}')
print(f'Label: {np.shape(label)}')
print(f'x_train: {np.shape(x_train)}')
print(f'y_train: {np.shape(y_train)}')
print(f'x_val: {np.shape(x_val)}')
print(f'y_val: {np.shape(y_val)}')
print(f'x_test: {np.shape(x_test)}')
print(f'y_test: {np.shape(y_test)}')
# Out:
# Data: (3171, 128, 128, 3)
# Label: (3171, 4)
# x_train: (2536, 128, 128, 3)
# y_train: (2536, 4)
# x_val: (317, 128, 128, 3)
# y_val: (317, 4)
# x_test: (318, 128, 128, 3)
# y_test: (318, 4)

# %%
datagen = ImageDataGenerator(
        rotation_range=30,
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip=True,
        vertical_flip=True,
        shear_range = 10
)

# %%
def augment_image(image):
    original_image = np.reshape(image, (1, *image.shape))

    fig, axs = plt.subplots(1, 5, figsize=(15, 3))
    for i in range(5):
        augmented_image = datagen.flow(original_image, batch_size=1)[0][0]
        axs[i].imshow(augmented_image)
        axs[i].set_title(f'Augmented Image {i+1}')
    plt.show()

# %%
plt.imshow(data[0])
plt.title('Original Image')
plt.show()

# %%
augment_image(data[0])

# %%
early_stopping = EarlyStopping(patience=20, monitor='val_accuracy', restore_best_weights=True)

# %% [markdown]
# ## Deep Learning

# %%
def create_model():
    model = Sequential([
        Conv2D(64, 3, activation='relu', padding='same', input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3)),
        MaxPooling2D(2, 2),
        Conv2D(64, 3, activation='relu', padding='same'),
        MaxPooling2D(2, 2),
        Conv2D(32, 3, activation='relu', padding='same'),
        MaxPooling2D(2, 2),
        Conv2D(32, 3, activation='relu', padding='same'),
        MaxPooling2D(2, 2),
        Flatten(),
        Dense(64, activation='relu'),
        Dense(y_train.shape[1], activation='softmax')
    ])

    model.compile(loss=CategoricalCrossentropy(),
              optimizer=Adam(0.001),
              metrics=['accuracy'])

    return model

# %%
model = create_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 64)      1792
#
#  max_pooling2d (MaxPooling2  (None, 64, 64, 64)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 64)        36928
#
#  max_pooling2d_1 (MaxPoolin  (None, 32, 32, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 32)        18464
#
#  max_pooling2d_2 (MaxPoolin  (None, 16, 16, 32)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 32)        9248
#
#  max_pooling2d_3 (MaxPoolin  (None, 8, 8, 32)          0
#  g2D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 64)                131136
#
#  dense_1 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 197828 (772.77 KB)
# Trainable params: 197828 (772.77 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(datagen.flow(x_train, y_train, batch_size=BATCH_SIZE),
                    validation_data = (x_val, y_val),
                    epochs=50,
                    steps_per_epoch=x_train.shape[0] // BATCH_SIZE,
                    callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 79/79 [==============================] - 20s 164ms/step - loss: 1.1138 - accuracy: 0.5236 - val_loss: 0.7827 - val_accuracy: 0.6530
# Epoch 2/50
# 79/79 [==============================] - 12s 155ms/step - loss: 0.7407 - accuracy: 0.6769 - val_loss: 0.6899 - val_accuracy: 0.7508
# Epoch 3/50
# 79/79 [==============================] - 14s 174ms/step - loss: 0.5566 - accuracy: 0.7839 - val_loss: 0.3483 - val_accuracy: 0.8801
# Epoch 4/50
# 79/79 [==============================] - 13s 159ms/step - loss: 0.4083 - accuracy: 0.8423 - val_loss: 0.4634 - val_accuracy: 0.8233
# Epoch 5/50
# 79/79 [==============================] - 14s 174ms/step - loss: 0.3582 - accuracy: 0.8614 - val_loss: 0.2014 - val_accuracy: 0.9243
# Epoch 6/50
# 79/79 [==============================] - 14s 179ms/step - loss: 0.2883 - accuracy: 0.8902 - val_loss: 0.5368 - val_accuracy: 0.8233
# Epoch 7/50
# 79/79 [==============================] - 14s 178ms/step - loss: 0.2811 - accuracy: 0.9018 - val_loss: 0.2076 - val_accuracy: 0.9243
# Epoch 8/50
# 79/79 [==============================] - 14s 174ms/step - loss: 0.2810 - accuracy: 0.8950 - val_loss: 0.1508 - val_accuracy: 0.9590
# Epoch 9/50
# 79/79 [==============================] - 14s 172ms/step - loss: 0.2446 - accuracy: 0.9058 - val_loss: 0.3055 - val_accuracy: 0.9054
# Epoch 10/50
# 79/79 [==============================] - 14s 172ms/step - loss: 0.1904 - accuracy: 0.9313 - val_loss: 0.2584 - val_accuracy: 0.9022
# Epoch 11/50
# 79/79 [==============================] - 12s 155ms/step - loss: 0.2368 - accuracy: 0.9177 - val_loss: 0.1437 - val_accuracy: 0.9558
# Epoch 12/50
# 79/79 [==============================] - 14s 179ms/step - loss: 0.1783 - accuracy: 0.9321 - val_loss: 0.2156 - val_accuracy: 0.9401
# Epoch 13/50
# 79/79 [==============================] - 14s 172ms/step - loss: 0.2208 - accuracy: 0.9201 - val_loss: 0.1595 - val_accuracy: 0.9495
# Epoch 14/50
# 79/79 [==============================] - 12s 154ms/step - loss: 0.1711 - accuracy: 0.9373 - val_loss: 0.1454 - val_accuracy: 0.9558
# Epoch 15/50
# 79/79 [==============================] - 14s 173ms/step - loss: 0.1980 - accuracy: 0.9269 - val_loss: 0.1566 - val_accuracy: 0.9558
# Epoch 16/50
# 79/79 [==============================] - 14s 175ms/step - loss: 0.1540 - accuracy: 0.9477 - val_loss: 0.2079 - val_accuracy: 0.9306
# Epoch 17/50
# 79/79 [==============================] - 13s 168ms/step - loss: 0.1530 - accuracy: 0.9493 - val_loss: 0.1076 - val_accuracy: 0.9590
# Epoch 18/50
# 79/79 [==============================] - 12s 149ms/step - loss: 0.1361 - accuracy: 0.9501 - val_loss: 0.0895 - val_accuracy: 0.9748
# Epoch 19/50
# 79/79 [==============================] - 13s 166ms/step - loss: 0.1448 - accuracy: 0.9481 - val_loss: 0.4285 - val_accuracy: 0.8707
# Epoch 20/50
# 79/79 [==============================] - 14s 174ms/step - loss: 0.1383 - accuracy: 0.9517 - val_loss: 0.0748 - val_accuracy: 0.9779
# Epoch 21/50
# 79/79 [==============================] - 14s 180ms/step - loss: 0.1447 - accuracy: 0.9461 - val_loss: 0.0750 - val_accuracy: 0.9716
# Epoch 22/50
# 79/79 [==============================] - 14s 176ms/step - loss: 0.1276 - accuracy: 0.9569 - val_loss: 0.0605 - val_accuracy: 0.9842
# Epoch 23/50
# 79/79 [==============================] - 14s 179ms/step - loss: 0.1240 - accuracy: 0.9589 - val_loss: 0.0944 - val_accuracy: 0.9779
# Epoch 24/50
# 79/79 [==============================] - 14s 173ms/step - loss: 0.0966 - accuracy: 0.9613 - val_loss: 0.1398 - val_accuracy: 0.9653
# Epoch 25/50
# 79/79 [==============================] - 12s 153ms/step - loss: 0.0810 - accuracy: 0.9684 - val_loss: 0.0611 - val_accuracy: 0.9842
# Epoch 26/50
# 79/79 [==============================] - 14s 171ms/step - loss: 0.0710 - accuracy: 0.9736 - val_loss: 0.0923 - val_accuracy: 0.9811
# Epoch 27/50
# 79/79 [==============================] - 13s 167ms/step - loss: 0.0900 - accuracy: 0.9625 - val_loss: 0.1255 - val_accuracy: 0.9590
# Epoch 28/50
# 79/79 [==============================] - 12s 148ms/step - loss: 0.0600 - accuracy: 0.9784 - val_loss: 0.0481 - val_accuracy: 0.9937
# Epoch 29/50
# 79/79 [==============================] - 14s 175ms/step - loss: 0.0730 - accuracy: 0.9756 - val_loss: 0.0707 - val_accuracy: 0.9748
# Epoch 30/50
# 79/79 [==============================] - 14s 172ms/step - loss: 0.0998 - accuracy: 0.9617 - val_loss: 0.2847 - val_accuracy: 0.9274
# Epoch 31/50
# 79/79 [==============================] - 14s 172ms/step - loss: 0.0718 - accuracy: 0.9776 - val_loss: 0.0444 - val_accuracy: 0.9874
# Epoch 32/50
# 79/79 [==============================] - 14s 172ms/step - loss: 0.0454 - accuracy: 0.9828 - val_loss: 0.0557 - val_accuracy: 0.9937
# Epoch 33/50
# 79/79 [==============================] - 13s 160ms/step - loss: 0.0794 - accuracy: 0.9732 - val_loss: 0.0758 - val_accuracy: 0.9748
# Epoch 34/50
# 79/79 [==============================] - 14s 173ms/step - loss: 0.0615 - accuracy: 0.9808 - val_loss: 0.0627 - val_accuracy: 0.9842
# Epoch 35/50
# 79/79 [==============================] - 14s 173ms/step - loss: 0.0362 - accuracy: 0.9864 - val_loss: 0.0674 - val_accuracy: 0.9811
# Epoch 36/50
# 79/79 [==============================] - 14s 173ms/step - loss: 0.1436 - accuracy: 0.9521 - val_loss: 0.0678 - val_accuracy: 0.9748
# Epoch 37/50
# 79/79 [==============================] - 12s 151ms/step - loss: 0.0489 - accuracy: 0.9848 - val_loss: 0.0742 - val_accuracy: 0.9779
# Epoch 38/50
# 79/79 [==============================] - 14s 178ms/step - loss: 0.0620 - accuracy: 0.9800 - val_loss: 0.0749 - val_accuracy: 0.9811
# Epoch 39/50
# 79/79 [==============================] - 14s 176ms/step - loss: 0.0381 - accuracy: 0.9848 - val_loss: 0.0403 - val_accuracy: 0.9874
# Epoch 40/50
# 79/79 [==============================] - 14s 174ms/step - loss: 0.0880 - accuracy: 0.9685 - val_loss: 0.0412 - val_accuracy: 0.9905
# Epoch 41/50
# 79/79 [==============================] - 12s 148ms/step - loss: 0.0645 - accuracy: 0.9796 - val_loss: 0.0373 - val_accuracy: 0.9905
# Epoch 42/50
# 79/79 [==============================] - 14s 171ms/step - loss: 0.0332 - accuracy: 0.9872 - val_loss: 0.0364 - val_accuracy: 0.9874
# Epoch 43/50
# 79/79 [==============================] - 12s 156ms/step - loss: 0.0381 - accuracy: 0.9836 - val_loss: 0.0685 - val_accuracy: 0.9653
# Epoch 44/50
# 79/79 [==============================] - 14s 172ms/step - loss: 0.0290 - accuracy: 0.9908 - val_loss: 0.2212 - val_accuracy: 0.9653
# Epoch 45/50
# 79/79 [==============================] - 12s 150ms/step - loss: 0.0550 - accuracy: 0.9828 - val_loss: 0.0294 - val_accuracy: 0.9905
# Epoch 46/50
# 79/79 [==============================] - 12s 157ms/step - loss: 0.0457 - accuracy: 0.9828 - val_loss: 0.0698 - val_accuracy: 0.9653
# Epoch 47/50
# 79/79 [==============================] - 14s 173ms/step - loss: 0.0524 - accuracy: 0.9840 - val_loss: 0.0406 - val_accuracy: 0.9905
# Epoch 48/50
# 79/79 [==============================] - 14s 172ms/step - loss: 0.0477 - accuracy: 0.9832 - val_loss: 0.0499 - val_accuracy: 0.9779

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
y_pred = model.predict(x_test)
y_pred = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)
print(classification_report(y_true, y_pred, target_names=class_total))
# Out:
# 10/10 [==============================] - 1s 53ms/step
#                           precision    recall  f1-score   support
#
#       Apple___Apple_scab       0.96      0.91      0.93        55
#        Apple___Black_rot       0.99      0.99      0.99        67
# Apple___Cedar_apple_rust       1.00      1.00      1.00        26
#          Apple___healthy       0.98      0.99      0.99       170
#
#                 accuracy                           0.98       318
#                macro avg       0.98      0.97      0.98       318
#             weighted avg       0.98      0.98      0.98       318

# %%
conf_matrix = confusion_matrix(y_true, y_pred)

print(conf_matrix)
# Out:
# [[ 50   1   0   4]
#  [  1  66   0   0]
#  [  0   0  26   0]
#  [  1   0   0 169]]

# %%
plt.imshow(conf_matrix, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# ## Pre trained model using MobileNetV2

# %%
base_model = MobileNetV2(
    include_top=False,
    weights='imagenet',
    input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3)
)

for layer in base_model.layers:
    layer.trainable = False

def pretrained_model():
    model = Sequential([
        base_model,
        Flatten(),
        Dense(64, activation='relu'),
        Dense(y_train.shape[1], activation='softmax')
    ])

    model.compile(loss=CategoricalCrossentropy(),
              optimizer=Adam(0.001),
              metrics=['accuracy'])

    return model
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_128_no_top.h5
# 9406464/9406464 [==============================] - 1s 0us/step

# %%
pretrained_model = pretrained_model()
pretrained_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_128 (Func  (None, 4, 4, 1280)        2257984
#  tional)
#
#  flatten_1 (Flatten)         (None, 20480)             0
#
#  dense_2 (Dense)             (None, 64)                1310784
#
#  dense_3 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 3569028 (13.61 MB)
# Trainable params: 1311044 (5.00 MB)
# Non-trainable params: 2257984 (8.61 MB)
# _________________________________________________________________

# %%
pretrained_history = pretrained_model.fit(datagen.flow(x_train, y_train, batch_size=BATCH_SIZE),
                    validation_data = (x_val, y_val),
                    epochs=50,
                    steps_per_epoch=x_train.shape[0] // BATCH_SIZE,
                    callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 79/79 [==============================] - 20s 202ms/step - loss: 0.7438 - accuracy: 0.8419 - val_loss: 0.1889 - val_accuracy: 0.9432
# Epoch 2/50
# 79/79 [==============================] - 12s 148ms/step - loss: 0.1344 - accuracy: 0.9545 - val_loss: 0.1860 - val_accuracy: 0.9432
# Epoch 3/50
# 79/79 [==============================] - 15s 185ms/step - loss: 0.1184 - accuracy: 0.9645 - val_loss: 0.1555 - val_accuracy: 0.9621
# Epoch 4/50
# 79/79 [==============================] - 12s 157ms/step - loss: 0.1343 - accuracy: 0.9577 - val_loss: 0.1047 - val_accuracy: 0.9779
# Epoch 5/50
# 79/79 [==============================] - 14s 175ms/step - loss: 0.0966 - accuracy: 0.9735 - val_loss: 0.0646 - val_accuracy: 0.9842
# Epoch 6/50
# 79/79 [==============================] - 14s 172ms/step - loss: 0.0646 - accuracy: 0.9772 - val_loss: 0.0958 - val_accuracy: 0.9716
# Epoch 7/50
# 79/79 [==============================] - 14s 173ms/step - loss: 0.0709 - accuracy: 0.9780 - val_loss: 0.0570 - val_accuracy: 0.9811
# Epoch 8/50
# 79/79 [==============================] - 13s 171ms/step - loss: 0.0657 - accuracy: 0.9736 - val_loss: 0.0578 - val_accuracy: 0.9748
# Epoch 9/50
# 79/79 [==============================] - 12s 148ms/step - loss: 0.0701 - accuracy: 0.9748 - val_loss: 0.1052 - val_accuracy: 0.9685
# Epoch 10/50
# 79/79 [==============================] - 14s 180ms/step - loss: 0.0578 - accuracy: 0.9788 - val_loss: 0.0638 - val_accuracy: 0.9779
# Epoch 11/50
# 79/79 [==============================] - 14s 174ms/step - loss: 0.0617 - accuracy: 0.9788 - val_loss: 0.0522 - val_accuracy: 0.9811
# Epoch 12/50
# 79/79 [==============================] - 13s 168ms/step - loss: 0.0589 - accuracy: 0.9744 - val_loss: 0.0735 - val_accuracy: 0.9811
# Epoch 13/50
# 79/79 [==============================] - 12s 148ms/step - loss: 0.0526 - accuracy: 0.9808 - val_loss: 0.0745 - val_accuracy: 0.9811
# Epoch 14/50
# 79/79 [==============================] - 13s 164ms/step - loss: 0.0321 - accuracy: 0.9884 - val_loss: 0.0705 - val_accuracy: 0.9779
# Epoch 15/50
# 79/79 [==============================] - 14s 179ms/step - loss: 0.0678 - accuracy: 0.9780 - val_loss: 0.0629 - val_accuracy: 0.9811
# Epoch 16/50
# 79/79 [==============================] - 11s 142ms/step - loss: 0.0453 - accuracy: 0.9864 - val_loss: 0.0832 - val_accuracy: 0.9748
# Epoch 17/50
# 79/79 [==============================] - 14s 173ms/step - loss: 0.0342 - accuracy: 0.9888 - val_loss: 0.0440 - val_accuracy: 0.9905
# Epoch 18/50
# 79/79 [==============================] - 13s 170ms/step - loss: 0.0359 - accuracy: 0.9856 - val_loss: 0.0342 - val_accuracy: 0.9905
# Epoch 19/50
# 79/79 [==============================] - 13s 165ms/step - loss: 0.0308 - accuracy: 0.9880 - val_loss: 0.0325 - val_accuracy: 0.9842
# Epoch 20/50
# 79/79 [==============================] - 11s 142ms/step - loss: 0.0346 - accuracy: 0.9872 - val_loss: 0.0356 - val_accuracy: 0.9842
# Epoch 21/50
# 79/79 [==============================] - 13s 166ms/step - loss: 0.0406 - accuracy: 0.9844 - val_loss: 0.0650 - val_accuracy: 0.9842
# Epoch 22/50
# 79/79 [==============================] - 13s 171ms/step - loss: 0.0489 - accuracy: 0.9856 - val_loss: 0.1227 - val_accuracy: 0.9779
# Epoch 23/50
# 79/79 [==============================] - 13s 158ms/step - loss: 0.0314 - accuracy: 0.9896 - val_loss: 0.0570 - val_accuracy: 0.9842
# Epoch 24/50
# 79/79 [==============================] - 14s 172ms/step - loss: 0.0285 - accuracy: 0.9904 - val_loss: 0.0642 - val_accuracy: 0.9811
# Epoch 25/50
# 79/79 [==============================] - 14s 179ms/step - loss: 0.0298 - accuracy: 0.9908 - val_loss: 0.0740 - val_accuracy: 0.9779
# Epoch 26/50
# 79/79 [==============================] - 13s 161ms/step - loss: 0.0331 - accuracy: 0.9916 - val_loss: 0.0263 - val_accuracy: 0.9842
# Epoch 27/50
# 79/79 [==============================] - 14s 172ms/step - loss: 0.0328 - accuracy: 0.9880 - val_loss: 0.0407 - val_accuracy: 0.9874
# Epoch 28/50
# 79/79 [==============================] - 14s 173ms/step - loss: 0.0356 - accuracy: 0.9864 - val_loss: 0.0796 - val_accuracy: 0.9779
# Epoch 29/50
# 79/79 [==============================] - 13s 168ms/step - loss: 0.0378 - accuracy: 0.9884 - val_loss: 0.1102 - val_accuracy: 0.9748
# Epoch 30/50
# 79/79 [==============================] - 11s 143ms/step - loss: 0.0477 - accuracy: 0.9844 - val_loss: 0.0634 - val_accuracy: 0.9842
# Epoch 31/50
# 79/79 [==============================] - 13s 162ms/step - loss: 0.0311 - accuracy: 0.9900 - val_loss: 0.1153 - val_accuracy: 0.9685
# Epoch 32/50
# 79/79 [==============================] - 13s 171ms/step - loss: 0.0301 - accuracy: 0.9876 - val_loss: 0.0688 - val_accuracy: 0.9811
# Epoch 33/50
# 79/79 [==============================] - 14s 171ms/step - loss: 0.0222 - accuracy: 0.9928 - val_loss: 0.0586 - val_accuracy: 0.9842
# Epoch 34/50
# 79/79 [==============================] - 14s 172ms/step - loss: 0.0211 - accuracy: 0.9924 - val_loss: 0.0773 - val_accuracy: 0.9779
# Epoch 35/50
# 79/79 [==============================] - 12s 155ms/step - loss: 0.0331 - accuracy: 0.9912 - val_loss: 0.0811 - val_accuracy: 0.9811
# Epoch 36/50
# 79/79 [==============================] - 14s 176ms/step - loss: 0.0359 - accuracy: 0.9872 - val_loss: 0.1851 - val_accuracy: 0.9653
# Epoch 37/50
# 79/79 [==============================] - 14s 176ms/step - loss: 0.0302 - accuracy: 0.9896 - val_loss: 0.1282 - val_accuracy: 0.9842

# %%
acc = pretrained_history.history['accuracy']
val_acc = pretrained_history.history['val_accuracy']
loss = pretrained_history.history['loss']
val_loss = pretrained_history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
y_pred = pretrained_model.predict(x_test)
y_pred = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)
print(classification_report(y_true, y_pred, target_names=class_total))
# Out:
# 10/10 [==============================] - 2s 101ms/step
#                           precision    recall  f1-score   support
#
#       Apple___Apple_scab       0.98      0.96      0.97        55
#        Apple___Black_rot       1.00      1.00      1.00        67
# Apple___Cedar_apple_rust       1.00      1.00      1.00        26
#          Apple___healthy       0.99      0.99      0.99       170
#
#                 accuracy                           0.99       318
#                macro avg       0.99      0.99      0.99       318
#             weighted avg       0.99      0.99      0.99       318

# %%
conf_matrix = confusion_matrix(y_true, y_pred)

print(conf_matrix)
# Out:
# [[ 53   0   0   2]
#  [  0  67   0   0]
#  [  0   0  26   0]
#  [  1   0   0 169]]

# %%
plt.imshow(conf_matrix, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# ## PCA and SVM

# %%
from sklearn.decomposition import PCA
from sklearn.svm import SVC

# %%
x_train_new = x_train.reshape((len(x_train), -1))
x_test_new = x_test.reshape((len(x_test), -1))
y_train_new = np.argmax(y_train, axis=1)
y_test_new = np.argmax(y_test, axis=1)
data_new = data.reshape((len(data), -1))

# %%
n_components = 500
pca = PCA(n_components=n_components)
pca.fit_transform(data_new)
X_train_pca = pca.transform(x_train_new)
X_test_pca = pca.transform(x_test_new)

# %%
X_train_pca.shape
# Out:
# (2536, 500)

# %%
X_test_pca.shape
# Out:
# (318, 500)

# %%
svm_classifier = SVC()
svm_classifier.fit(X_train_pca, y_train_new)
# Out:
# SVC()

# %%
y_pred = svm_classifier.predict(X_test_pca)
print(classification_report(y_test_new, y_pred, target_names=class_total))
# Out:
#                           precision    recall  f1-score   support
#
#       Apple___Apple_scab       0.81      0.87      0.84        55
#        Apple___Black_rot       0.91      0.90      0.90        67
# Apple___Cedar_apple_rust       0.88      0.88      0.88        26
#          Apple___healthy       0.96      0.95      0.96       170
#
#                 accuracy                           0.92       318
#                macro avg       0.89      0.90      0.90       318
#             weighted avg       0.92      0.92      0.92       318

# %%
conf_matrix = confusion_matrix(y_test_new, y_pred)

print(conf_matrix)
# Out:
# [[ 48   2   2   3]
#  [  5  60   0   2]
#  [  1   1  23   1]
#  [  5   3   1 161]]

# %%
plt.imshow(conf_matrix, cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
